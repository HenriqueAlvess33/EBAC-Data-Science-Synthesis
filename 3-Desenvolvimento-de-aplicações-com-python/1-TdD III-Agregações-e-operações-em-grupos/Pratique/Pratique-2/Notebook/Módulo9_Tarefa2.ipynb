# %% [markdown]
# # Livro para consulta:
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import requests

# %matplotlib inline

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 2. Carregando o dataframe SINASC <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
sinasc_raw = pd.read_csv("./input/SINASC_RO_2019.csv")
sinasc_raw.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  CODMUNRES  \
# 0      8 a 11 anos         NaN         0.0         0.0     110001
# 1      8 a 11 anos    999992.0         1.0         0.0     110001
# 2      8 a 11 anos    513205.0         2.0         0.0     110001
# 3  12 anos ou mais    231205.0         0.0         0.0     110037
# 4      8 a 11 anos    999992.0         1.0         0.0     110001
#
#           GESTACAO GRAVIDEZ    PARTO  CONSULTAS      DTNASC  HORANASC  \
# 0  37 a 41 semanas    Única  Cesáreo          4  2019-02-19    1620.0
# 1  37 a 41 semanas    Única  Cesáreo          4  2019-02-21    1830.0
# 2  37 a 41 semanas    Única  Cesáreo          4  2019-02-25     915.0
# 3  37 a 41 semanas    Única  Cesáreo          3  2019-03-20     835.0
# 4  37 a 41 semanas    Única  Cesáreo          4  2019-03-23     750.0
#
#         SEXO  APGAR1  APGAR5 RACACOR  PESO  IDANOMAL  DTCADASTRO CODANOMAL  \
# 0  Masculino     9.0    10.0  Branca  3685       2.0  2019-03-08       NaN
# 1   Feminino     8.0     9.0  Branca  3055       2.0  2019-03-08       NaN
# 2   Feminino     8.0    10.0  Branca  3460       2.0  2019-03-08       NaN
# 3   Feminino     9.0    10.0   Parda  2982       2.0  2019-04-03       NaN
# 4   Feminino     8.0    10.0   Parda  3310       2.0  2019-04-03       NaN
#
#    NUMEROLOTE VERSAOSIST   DTRECEBIM  DIFDATA  DTRECORIGA  NATURALMAE  \
# 0    20190004     3.2.01  2019-03-08       17         NaN       811.0
# 1    20190004     3.2.01  2019-03-08       15         NaN       811.0
# 2    20190004     3.2.01  2019-03-08       11         NaN       841.0
# 3    20190005     3.2.01  2019-04-09       20         NaN       841.0
# 4    20190005     3.2.01  2019-04-09       17         NaN       811.0
#
#    CODMUNNATU  CODUFNATU  ESCMAE2010  SERIESCMAE   DTNASCMAE  RACACORMAE  \
# 0    110001.0       11.0         3.0         NaN  20121999.0         1.0
# 1    110015.0       11.0         3.0         NaN  27041989.0         1.0
# 2    410045.0       41.0         3.0         NaN   6031981.0         1.0
# 3    410480.0       41.0         5.0         NaN  15071988.0         4.0
# 4    110001.0       11.0         3.0         NaN  12111988.0         4.0
#
#    QTDGESTANT  QTDPARTNOR  QTDPARTCES  IDADEPAI  DTULTMENST  SEMAGESTAC  \
# 0         0.0         0.0         0.0      26.0  15052018.0        39.0
# 1         1.0         0.0         1.0      24.0  27052018.0        38.0
# 2         2.0         1.0         1.0      32.0  18052018.0        40.0
# 3         0.0         0.0         0.0      24.0  25062018.0        38.0
# 4         1.0         0.0         1.0      27.0  27062018.0        38.0
#
#    TPMETESTIM  CONSPRENAT  MESPRENAT  TPAPRESENT  STTRABPART  STCESPARTO  \
# 0         8.0         8.0        1.0         1.0         2.0         2.0
# 1         8.0        10.0        2.0         1.0         2.0         2.0
# 2         8.0         8.0        1.0         2.0         2.0         2.0
# 3         8.0         6.0        2.0         1.0         2.0         1.0
# 4         8.0         8.0        2.0         1.0         2.0         1.0
#
#    TPNASCASSI  TPFUNCRESP  TPDOCRESP  DTDECLARAC  ESCMAEAGR1  STDNEPIDEM  \
# 0         1.0         2.0        3.0  19022019.0        12.0           0
# 1         1.0         5.0        4.0  21022019.0        12.0           0
# 2         1.0         2.0        4.0  25022019.0        12.0           0
# 3         1.0         2.0        3.0  20032019.0         8.0           0
# 4         1.0         2.0        3.0  23032019.0        12.0           0
#
#    STDNNOVA  CODPAISRES  TPROBSON  PARIDADE  KOTELCHUCK  CONTADOR  \
# 0         1           1         1         0           5         1
# 1         1           1         5         1           5         2
# 2         1           1         7         1           5         3
# 3         1           1         2         0           4         4
# 4         1           1         5         1           5         5
#
#   munResStatus munResTipo               munResNome  munResUf  munResLat  \
# 0        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia  -11.93554
# 1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia  -11.93554
# 2        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia  -11.93554
# 3        ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia  -12.13178
# 4        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia  -11.93554
#
#    munResLon  munResAlt  munResArea
# 0  -61.99982      338.0    7067.025
# 1  -61.99982      338.0    7067.025
# 2  -61.99982      338.0    7067.025
# 3  -61.85308      397.0    3958.273
# 4  -61.99982      338.0    7067.025

# %%
sinasc_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27028 entries, 0 to 27027
# Data columns (total 69 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ORIGEM        27028 non-null  int64
#  1   CODESTAB      26913 non-null  float64
#  2   CODMUNNASC    27028 non-null  int64
#  3   LOCNASC       27028 non-null  int64
#  4   IDADEMAE      27028 non-null  int64
#  5   ESTCIVMAE     26711 non-null  float64
#  6   ESCMAE        26716 non-null  object
#  7   CODOCUPMAE    24121 non-null  float64
#  8   QTDFILVIVO    25455 non-null  float64
#  9   QTDFILMORT    24930 non-null  float64
#  10  CODMUNRES     27028 non-null  int64
#  11  GESTACAO      25796 non-null  object
#  12  GRAVIDEZ      26949 non-null  object
#  13  PARTO         26979 non-null  object
#  14  CONSULTAS     27028 non-null  int64
#  15  DTNASC        27028 non-null  object
#  16  HORANASC      27007 non-null  float64
#  17  SEXO          27024 non-null  object
#  18  APGAR1        26932 non-null  float64
#  19  APGAR5        26925 non-null  float64
#  20  RACACOR       26381 non-null  object
#  21  PESO          27028 non-null  int64
#  22  IDANOMAL      26437 non-null  float64
#  23  DTCADASTRO    27028 non-null  object
#  24  CODANOMAL     214 non-null    object
#  25  NUMEROLOTE    27028 non-null  int64
#  26  VERSAOSIST    27028 non-null  object
#  27  DTRECEBIM     27028 non-null  object
#  28  DIFDATA       27028 non-null  int64
#  29  DTRECORIGA    0 non-null      float64
#  30  NATURALMAE    26730 non-null  float64
#  31  CODMUNNATU    26730 non-null  float64
#  32  CODUFNATU     26730 non-null  float64
#  33  ESCMAE2010    26779 non-null  float64
#  34  SERIESCMAE    14318 non-null  float64
#  35  DTNASCMAE     26988 non-null  float64
#  36  RACACORMAE    26367 non-null  float64
#  37  QTDGESTANT    25816 non-null  float64
#  38  QTDPARTNOR    25149 non-null  float64
#  39  QTDPARTCES    25237 non-null  float64
#  40  IDADEPAI      7607 non-null   float64
#  41  DTULTMENST    16956 non-null  float64
#  42  SEMAGESTAC    25790 non-null  float64
#  43  TPMETESTIM    25790 non-null  float64
#  44  CONSPRENAT    26098 non-null  float64
#  45  MESPRENAT     24161 non-null  float64
#  46  TPAPRESENT    26763 non-null  float64
#  47  STTRABPART    26081 non-null  float64
#  48  STCESPARTO    26281 non-null  float64
#  49  TPNASCASSI    26967 non-null  float64
#  50  TPFUNCRESP    26961 non-null  float64
#  51  TPDOCRESP     27014 non-null  float64
#  52  DTDECLARAC    26976 non-null  float64
#  53  ESCMAEAGR1    26779 non-null  float64
#  54  STDNEPIDEM    27028 non-null  int64
#  55  STDNNOVA      27028 non-null  int64
#  56  CODPAISRES    27028 non-null  int64
#  57  TPROBSON      27028 non-null  int64
#  58  PARIDADE      27028 non-null  int64
#  59  KOTELCHUCK    27028 non-null  int64
#  60  CONTADOR      27028 non-null  int64
#  61  munResStatus  27028 non-null  object
#  62  munResTipo    27028 non-null  object
#  63  munResNome    27028 non-null  object
#  64  munResUf      27028 non-null  object
#  65  munResLat     27027 non-null  float64
#  66  munResLon     27027 non-null  float64
#  67  munResAlt     27027 non-null  float64
#  68  munResArea    27027 non-null  float64
# dtypes: float64(38), int64(16), object(15)
# memory usage: 14.2+ MB

# %% [markdown]
# # Tarefa 2

# %% [markdown]
# ### 1. Crie 2 faixas de Latitude do município (munResLat) sendo uma acima e outra abaixo de -10.5 e aplique o groupby usando essas faixas como chave e realize operações de soma, media, minimo, maximo, mediana, desvio padrao, variancia pra pelo menos 2 variáveis numéricas ainda não utilizadas

# %%
sinasc_raw["faixa_latitude"] = pd.cut(
    sinasc_raw["munResLat"],
    bins=[-float("inf"), -10.5, float("inf")],
    labels=["Abaixo de -10.5", "Acima de -10.5"],
)

# %%
resultados = sinasc_raw.groupby("faixa_latitude").agg(
    {
        "IDADEMAE": [
            ("soma", "sum"),
            ("média", "mean"),
            ("mínimo", "min"),
            ("máximo", "max"),
            ("mediana", "median"),
            ("desvio padrão", "std"),
            ("variância", "var"),
        ],
        "QTDFILVIVO":[
            ("soma", "sum"),
            ("média", "mean"),
            ("mínimo", "min"),
            ("máximo", "max"),
            ("mediana", "median"),
            ("desvio padrão", "std"),
            ("variância", "var")]
    },
)
resultados.head()
# Out:
# C:\Users\hfasa\AppData\Local\Temp\ipykernel_32692\215053699.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   resultados = sinasc_raw.groupby("faixa_latitude").agg(
#                 IDADEMAE                                                 \
#                     soma      média mínimo máximo mediana desvio padrão
# faixa_latitude
# Abaixo de -10.5   340143  26.178943     12     53    26.0      6.320385
# Acima de -10.5    365094  26.014964     11     52    25.0      6.447663
#
#                            QTDFILVIVO                                  \
#                  variância       soma     média mínimo máximo mediana
# faixa_latitude
# Abaixo de -10.5  39.947272    12600.0  0.980011    0.0   30.0     1.0
# Acima de -10.5   41.572355    14226.0  1.129317    0.0   12.0     1.0
#
#
#                 desvio padrão variância
# faixa_latitude
# Abaixo de -10.5      1.138300  1.295727
# Acima de -10.5       1.198613  1.436674

# %% [markdown]
# ### 2. Crie 2 faixas da área dos municípios (munResArea) sendo uma acima e outra abaixo de 3000 e aplique o groupby usando essas faixas como chave e realize operações de soma, media, minimo, maximo, mediana, desvio padrao, variancia pra pelo menos 2 variáveis numéricas ainda não utilizadas

# %%
sinasc_raw["faixa_area"] = pd.cut(
    sinasc_raw["munResArea"],
    bins=[-float("inf"), 3000, float("inf")],
    labels=["Abaixo de 3000", "Acima de 3000"],
)

# %%
resultados = sinasc_raw.groupby('faixa_area').agg({'KOTELCHUCK': [
            ("soma", "sum"),
            ("média", "mean"),
            ("mínimo", "min"),
            ("máximo", "max"),
            ("mediana", "median"),
            ("desvio padrão", "std"),
            ("variância", "var")
        ], 'QTDFILMORT':[
            ("soma", "sum"),
            ("média", "mean"),
            ("mínimo", "min"),
            ("máximo", "max"),
            ("mediana", "median"),
            ("desvio padrão", "std"),
            ("variância", "var"),
]})

resultados.head()
# Out:
# C:\Users\hfasa\AppData\Local\Temp\ipykernel_32692\130797693.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   resultados = sinasc_raw.groupby('faixa_area').agg({'KOTELCHUCK': [
#                KOTELCHUCK                                                \
#                      soma     média mínimo máximo mediana desvio padrão
# faixa_area
# Abaixo de 3000      24494  4.693236      1      9     5.0      1.456135
# Acima de 3000      109968  5.042553      1      9     5.0      2.182659
#
#                          QTDFILMORT                                  \
#                variância       soma     média mínimo máximo mediana
# faixa_area
# Abaixo de 3000  2.120328     1260.0  0.244803    0.0    4.0     0.0
# Acima de 3000   4.763998     5383.0  0.272116    0.0   28.0     0.0
#
#
#                desvio padrão variância
# faixa_area
# Abaixo de 3000      0.551215  0.303838
# Acima de 3000       0.629081  0.395743

# %% [markdown]
# ### 3. Determine faixas na variável munResAlt e aplique o groupby usando essas faixas como chave e realize operações de soma, media, minimo, maximo, mediana, desvio padrao, variancia pra pelo menos 2 variáveis numéricas ainda não utilizadas

# %%
min_altitude = sinasc_raw['munResAlt'].min()
min_altitude

max_altitude = sinasc_raw['munResAlt'].max()
max_altitude

print(f"Menor valor de munResAlt: {min_altitude}")
print(f"Maior valor de munResAlt: {max_altitude}")
# Out:
# Menor valor de munResAlt: 85.0
# Maior valor de munResAlt: 595.0

# %%
sinasc_raw["faixa_de_altitude"] = pd.cut(
    sinasc_raw["munResAlt"],
    bins=[-float("inf"), 100, 300, 500, float("inf")],
    labels=["Abaixo de 100", "Entre 100 e 300", "Entre 300 e 500", "Acima de 500"],
)

# %% [markdown]
# ### 4. Plote no mesmo grafico ao longo do tempo a idade media das mulheres de cada regiao imediatas de rondonia

# %%
imediatas = {
    "Candeias do Jamari": "Porto Velho",
    "Guajará-Mirim": "Porto Velho",
    "Itapuã do Oeste": "Porto Velho",
    "Nova Mamoré": "Porto Velho",
    "Porto Velho": "Porto Velho",
    "Ariquemes": "Ariquemes",
    "Alto Paraíso": "Ariquemes",
    "Buritis": "Ariquemes",
    "Cacaulândia": "Ariquemes",
    "Campo Novo de Rondônia": "Ariquemes",
    "Cujubim": "Ariquemes",
    "Monte Negro": "Ariquemes",
    "Rio Crespo": "Ariquemes",
    "Jaru": "Jaru",
    "Governador Jorge Teixeira": "Jaru",
    "Machadinho D'Oeste": "Jaru",
    "Theobroma": "Jaru",
    "Vale do Anari": "Jaru",
    "Alvorada D'Oeste": "Ji-Paraná",
    "Costa Marques": "Ji-Paraná",
    "Ji-Paraná": "Ji-Paraná",
    "Mirante da Serra": "Ji-Paraná",
    "Nova União": "Ji-Paraná",
    "Ouro Preto do Oeste": "Ji-Paraná",
    "Presidente Médici": "Ji-Paraná",
    "São Francisco do Guaporé": "Ji-Paraná",
    "São Miguel do Guaporé": "Ji-Paraná",
    "Seringueiras": "Ji-Paraná",
    "Teixeirópolis": "Ji-Paraná",
    "Urupá": "Ji-Paraná",
    "Vale do Paraíso": "Ji-Paraná",
    "Cacoal": "Cacoal",
    "Alta Floresta D'Oeste": "Cacoal",
    "Alto Alegre dos Parecis": "Cacoal",
    "Castanheiras": "Cacoal",
    "Espigão D'Oeste": "Cacoal",
    "Ministro Andreazza": "Cacoal",
    "Nova Brasilândia D'Oeste": "Cacoal",
    "Novo Horizonte do Oeste": "Cacoal",
    "Parecis": "Cacoal",
    "Pimenta Bueno": "Cacoal",
    "Primavera de Rondônia": "Cacoal",
    "Rolim de Moura": "Cacoal",
    "Santa Luzia D'Oeste": "Cacoal",
    "São Felipe D'Oeste": "Cacoal",
    "Vilhena": "Vilhena",
    "Cabixi": "Vilhena",
    "Cerejeiras": "Vilhena",
    "Chupinguaia": "Vilhena",
    "Colorado do Oeste": "Vilhena",
    "Corumbiara": "Vilhena",
    "Pimenteiras do Oeste": "Vilhena",
}
set(imediatas.values())
# Out:
# {'Ariquemes', 'Cacoal', 'Jaru', 'Ji-Paraná', 'Porto Velho', 'Vilhena'}

# %%
sinasc_raw['regiao_imediata'] = sinasc_raw['munResNome'].map(imediatas)

# %%
sinasc_raw['DTNASC'] = pd.to_datetime(sinasc_raw['DTNASC'])

# %%
sinasc_raw['ano_mes'] = sinasc_raw['DTNASC'].dt.to_period('M')

# %%
idade_media = sinasc_raw.groupby(['ano_mes', 'regiao_imediata'])['IDADEMAE'].mean().unstack()
idade_media
# Out:
# regiao_imediata  Ariquemes     Cacoal       Jaru  Ji-Paraná  Porto Velho  \
# ano_mes
# 2019-01          24.866412  26.350543  26.086667  25.792056    26.017668
# 2019-02          25.316239  25.969444  25.586777  26.417949    26.215000
# 2019-03          25.288660  26.319410  26.215686  25.490364    26.347207
# 2019-04          25.411972  26.235149  25.291667  26.075862    26.172336
# 2019-05          25.410256  26.031008  25.187050  25.931264    25.830470
# 2019-06          26.652510  25.845333  26.055944  26.272727    26.421628
# 2019-07          24.973783  26.780488  24.611111  25.809399    26.139903
# 2019-08          25.684615  26.539106  25.864865  25.938144    26.070588
# 2019-09          25.561644  26.779126  25.748299  25.640177    25.966435
# 2019-10          25.736111  26.335878  26.453125  26.246341    25.886473
# 2019-11          25.765432  26.770053  25.242424  27.313316    26.394737
# 2019-12          24.821577  26.207071  25.967105  26.482289    26.575567
#
# regiao_imediata    Vilhena
# ano_mes
# 2019-01          26.665049
# 2019-02          26.781818
# 2019-03          26.386667
# 2019-04          26.686099
# 2019-05          25.586207
# 2019-06          26.526627
# 2019-07          26.373057
# 2019-08          26.297436
# 2019-09          26.407407
# 2019-10          26.161435
# 2019-11          26.169725
# 2019-12          27.010753

# %%
plt.figure(figsize=(12,6))
for regiao in idade_media.columns:
    plt.plot(idade_media.index.to_timestamp(), idade_media[regiao], label=regiao)
    
plt.title('Idade Média das Mães ao Longo do Tempo por Região Imediata - Rondônia (2019)')

plt.xlabel('Tempo')

plt.ylabel('Idade Média')

plt.legend(title='Região Imediata')

plt.grid(True)

plt.tight_layout()

plt.show()

# %% [markdown]
# ### 5. Utilize a tabela do link abaixo e crie faixas utilizando o mapping e gere agrupamentos utilizando essas faixas como chave

# %% [markdown]
# ### 5.1 IDH
# A - https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_de_Rond%C3%B4nia_por_IDH-M

# %%
url = (
    "https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_de_Rond%C3%B4nia_por_IDH-M"
)
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; WIN64; x64)"
    "AppleWebKit/537.36 (KHTML, like Gecko)"
    "Chrome/124.0 Safari/537.36"
}

resp = requests.get(url, headers=headers)
resp.raise_for_status()

tables = pd.read_html(resp.text)
# Out:
# C:\Users\hfasa\AppData\Local\Temp\ipykernel_32692\2001052610.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text)

# %%
idh_table = tables[0]
idh_table.columns = ['Posição', 'Município', 'IDH', 'IDH_Renda', 'IDH_Longevidade', 'IDH_Educação']
idh_table = idh_table[['Posição', 'Município', 'IDH']].copy()
idh_table
# Out:
#               Posição                  Município                IDH
# 0    nenhum município           nenhum município   nenhum município
# 1          IDH-M alto                 IDH-M alto         IDH-M alto
# 2                   1                Porto Velho              0.736
# 3                   2                    Vilhena              0.731
# 4                   3                     Cacoal              0.718
# 5                   4                  Ji-Paraná              0.714
# 6                   5              Pimenta Bueno              0.710
# 7                   6                  Ariquemes              0.702
# 8                   7             Rolim de Moura              0.700
# 9         IDH-M médio                IDH-M médio        IDH-M médio
# 10                  8                 Cerejeiras              0.692
# 11                  9                       Jaru              0.689
# 12                 10          Colorado do Oeste              0.685
# 13                 11        Ouro Preto do Oeste              0.682
# 14                 12            Espigão d'Oeste              0.672
# 15                 13        Santa Luzia d'Oeste              0.670
# 16                 14       Pimenteiras do Oeste              0.665
# 17                 15          Presidente Médici              0.664
# 18                 16               Castanheiras              0.658
# 19                 17              Guajará-Mirim              0.657
# 20                 18                Chupinguaia              0.652
# 21                 19                     Cabixi              0.650
# 22                 20         Candeias do Jamari              0.649
# 23                 20         São Felipe d'Oeste              0.649
# 24                 22                Cacaulândia              0.646
# 25                 22      São Miguel do Guaporé              0.646
# 26                 24           Mirante da Serra              0.643
# 27                 24           Alvorada d'Oeste              0.643
# 28                 24              Teixeirópolis              0.643
# 29                 24   Nova Brasilândia d'Oeste              0.643
# 30                 24                 Rio Crespo              0.643
# 31                 29      Primavera de Rondônia              0.641
# 32                 29      Alta Floresta d'Oeste              0.641
# 33                 31         Ministro Andreazza              0.638
# 34                 32    Novo Horizonte do Oeste              0.634
# 35                 33            Vale do Paraíso              0.627
# 36                 34               Alto Paraíso              0.625
# 37                 35                    Parecis              0.617
# 38                 36                    Buritis              0.616
# 39                 37            Itapuã do Oeste              0.614
# 40                 38                 Corumbiara              0.613
# 41                 39                    Cujubim              0.612
# 42                 40              Costa Marques              0.611
# 43                 40   São Francisco do Guaporé              0.611
# 44                 42                      Urupá              0.609
# 45                 43                Monte Negro              0.607
# 46        IDH-M baixo                IDH-M baixo        IDH-M baixo
# 47                 44               Seringueiras              0.598
# 48                 45  Governador Jorge Teixeira              0.596
# 49                 45         Machadinho d'Oeste              0.596
# 50                 47     Campo Novo de Rondônia              0.593
# 51                 48    Alto Alegre dos Parecis              0.592
# 52                 49                  Theobroma              0.589
# 53                 50                 Nova União              0.587
# 54                 50                Nova Mamoré              0.587
# 55                 52              Vale do Anari              0.584
# 56  IDH-M muito baixo          IDH-M muito baixo  IDH-M muito baixo
# 57   nenhum município           nenhum município   nenhum município

# %%
idh_table.loc[:,'IDH'] = pd.to_numeric(idh_table['IDH'], errors='coerce')
idh_table.dropna(subset=['IDH'],inplace=True)
idh_table.head(n=5)
# Out:
#   Posição      Município    IDH
# 2       1    Porto Velho  0.736
# 3       2        Vilhena  0.731
# 4       3         Cacoal  0.718
# 5       4      Ji-Paraná  0.714
# 6       5  Pimenta Bueno   0.71

# %%
def categorize_idh (idh):
    if idh < 0.500:
        return 'Muito Baixo'
    elif idh < 0.600:
        return 'Baixo'
    elif idh < 0.700:
        return 'Médio'
    elif idh < 0.800:
        return 'Alto'
    else:
        return 'Muito Alto'

# %%
idh_table.loc[:,'faixa_idh'] = idh_table['IDH'].apply(categorize_idh)
idh_table.loc[idh_table['faixa_idh'] == 'Alto']
# Out:
#   Posição       Município    IDH faixa_idh
# 2       1     Porto Velho  0.736      Alto
# 3       2         Vilhena  0.731      Alto
# 4       3          Cacoal  0.718      Alto
# 5       4       Ji-Paraná  0.714      Alto
# 6       5   Pimenta Bueno   0.71      Alto
# 7       6       Ariquemes  0.702      Alto
# 8       7  Rolim de Moura    0.7      Alto

# %%
idh_table.head(n=5)
# Out:
#   Posição      Município    IDH faixa_idh
# 2       1    Porto Velho  0.736      Alto
# 3       2        Vilhena  0.731      Alto
# 4       3         Cacoal  0.718      Alto
# 5       4      Ji-Paraná  0.714      Alto
# 6       5  Pimenta Bueno   0.71      Alto

# %% [markdown]
# ### 5.2 IFDM
# B - https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_de_Rond%C3%B4nia_por_IFDM

# %%
url = 'https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_de_Rond%C3%B4nia_por_IFDM'

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; WIN64; x64)"
    "AppleWebKit/537.36 (KHTML, like Gecko)"
    "Chrome/124.0 Safari/537.36"
}

resp = requests.get(url, headers=headers)
resp.raise_for_status()

tables = pd.read_html(resp.text)
ifdm_table = tables[0]
ifdm_table.columns = ['Posição', 'Município', 'IFDM_Consolidado_2013']
ifdm_table.head(n=5)
# Out:
# C:\Users\hfasa\AppData\Local\Temp\ipykernel_32692\424159339.py:10: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text)
#                     Posição                 Município  \
# 0          nenhum município          nenhum município
# 1  Desenvolvimento moderado  Desenvolvimento moderado
# 2                        1º                 Ariquemes
# 3                        2º                   Vilhena
# 4                        3º             Pimenta Bueno
#
#       IFDM_Consolidado_2013
# 0          nenhum município
# 1  Desenvolvimento moderado
# 2                    0.7746
# 3                    0.7465
# 4                    0.7383

# %%
ifdm_table.loc[:,'IFDM_Consolidado_2013'] = pd.to_numeric(ifdm_table['IFDM_Consolidado_2013'], errors='coerce')
ifdm_table.dropna(subset=['IFDM_Consolidado_2013'], inplace=True)
ifdm_table
# Out:
#    Posição                  Município IFDM_Consolidado_2013
# 2       1º                  Ariquemes                0.7746
# 3       2º                    Vilhena                0.7465
# 4       3º              Pimenta Bueno                0.7383
# 5       4º                Porto Velho                0.7257
# 6       5º                  Ji-Paraná                0.7117
# 7       6º                     Cacoal                0.7111
# 8       7º        Santa Luzia d'Oeste                 0.685
# 9       8º             Rolim de Moura                0.6785
# 10      9º                Chupinguaia                0.6766
# 11     10º      São Miguel do Guaporé                0.6699
# 12     11º       Pimenteiras do Oeste                0.6501
# 13     12º              Teixeirópolis                  0.65
# 14     13º          Colorado do Oeste                0.6473
# 15     14º                       Jaru                 0.645
# 16     15º                 Rio Crespo                 0.643
# 17     16º      Primavera de Rondônia                0.6384
# 18     17º      Alta Floresta d'Oeste                0.6337
# 19     18º        Ouro Preto do Oeste                0.6261
# 20     19º   São Francisco do Guaporé                0.6214
# 21     20º         Candeias do Jamari                0.6199
# 22     20º                    Buritis                0.6199
# 23     22º         São Felipe d'Oeste                0.6153
# 24     23º          Presidente Médici                 0.614
# 25     24º                 Cerejeiras                0.6137
# 26     25º                Monte Negro                0.6016
# 27     26º                      Urupá                0.6006
# 29     27º            Espigão d'Oeste                0.5973
# 30     28º               Seringueiras                0.5922
# 31     29º           Alvorada d'Oeste                0.5919
# 32     30º            Itapuã do Oeste                0.5903
# 33     31º                     Cabixi                0.5887
# 34     32º    Novo Horizonte do Oeste                0.5858
# 35     33º   Nova Brasilândia d'Oeste                0.5857
# 36     34º            Vale do Paraíso                0.5818
# 37     35º                 Corumbiara                0.5759
# 38     36º               Alto Paraíso                0.5735
# 39     37º                Cacaulândia                0.5721
# 40     38º              Vale do Anari                 0.571
# 41     39º         Ministro Andreazza                0.5657
# 42     40º              Costa Marques                0.5626
# 43     41º                 Nova União                0.5571
# 44     42º              Guajará-Mirim                0.5541
# 45     43º           Mirante da Serra                0.5519
# 46     44º                    Parecis                0.5502
# 47     45º               Castanheiras                 0.543
# 48     46º                  Theobroma                0.5405
# 49     47º         Machadinho d'Oeste                0.5322
# 50     48º     Campo Novo de Rondônia                0.5272
# 51     49º                Nova Mamoré                0.5084
# 52     50º                    Cujubim                0.5055
# 53     51º    Alto Alegre dos Parecis                0.5046
# 54     52º  Governador Jorge Teixeira                0.4562

# %%
def categorize_ifdm(ifdm):
        if ifdm < 0.4:
            return 'Baixo'
        elif ifdm < 0.6:
            return 'Regular'
        elif ifdm < 0.8:
            return 'Moderado'
        else:
            return 'Alto'

# %%
ifdm_table.loc[:,'faixa_ifdm'] = ifdm_table['IFDM_Consolidado_2013'].apply(categorize_ifdm)
ifdm_table
# Out:
#    Posição                  Município IFDM_Consolidado_2013 faixa_ifdm
# 2       1º                  Ariquemes                0.7746   Moderado
# 3       2º                    Vilhena                0.7465   Moderado
# 4       3º              Pimenta Bueno                0.7383   Moderado
# 5       4º                Porto Velho                0.7257   Moderado
# 6       5º                  Ji-Paraná                0.7117   Moderado
# 7       6º                     Cacoal                0.7111   Moderado
# 8       7º        Santa Luzia d'Oeste                 0.685   Moderado
# 9       8º             Rolim de Moura                0.6785   Moderado
# 10      9º                Chupinguaia                0.6766   Moderado
# 11     10º      São Miguel do Guaporé                0.6699   Moderado
# 12     11º       Pimenteiras do Oeste                0.6501   Moderado
# 13     12º              Teixeirópolis                  0.65   Moderado
# 14     13º          Colorado do Oeste                0.6473   Moderado
# 15     14º                       Jaru                 0.645   Moderado
# 16     15º                 Rio Crespo                 0.643   Moderado
# 17     16º      Primavera de Rondônia                0.6384   Moderado
# 18     17º      Alta Floresta d'Oeste                0.6337   Moderado
# 19     18º        Ouro Preto do Oeste                0.6261   Moderado
# 20     19º   São Francisco do Guaporé                0.6214   Moderado
# 21     20º         Candeias do Jamari                0.6199   Moderado
# 22     20º                    Buritis                0.6199   Moderado
# 23     22º         São Felipe d'Oeste                0.6153   Moderado
# 24     23º          Presidente Médici                 0.614   Moderado
# 25     24º                 Cerejeiras                0.6137   Moderado
# 26     25º                Monte Negro                0.6016   Moderado
# 27     26º                      Urupá                0.6006   Moderado
# 29     27º            Espigão d'Oeste                0.5973    Regular
# 30     28º               Seringueiras                0.5922    Regular
# 31     29º           Alvorada d'Oeste                0.5919    Regular
# 32     30º            Itapuã do Oeste                0.5903    Regular
# 33     31º                     Cabixi                0.5887    Regular
# 34     32º    Novo Horizonte do Oeste                0.5858    Regular
# 35     33º   Nova Brasilândia d'Oeste                0.5857    Regular
# 36     34º            Vale do Paraíso                0.5818    Regular
# 37     35º                 Corumbiara                0.5759    Regular
# 38     36º               Alto Paraíso                0.5735    Regular
# 39     37º                Cacaulândia                0.5721    Regular
# 40     38º              Vale do Anari                 0.571    Regular
# 41     39º         Ministro Andreazza                0.5657    Regular
# 42     40º              Costa Marques                0.5626    Regular
# 43     41º                 Nova União                0.5571    Regular
# 44     42º              Guajará-Mirim                0.5541    Regular
# 45     43º           Mirante da Serra                0.5519    Regular
# 46     44º                    Parecis                0.5502    Regular
# 47     45º               Castanheiras                 0.543    Regular
# 48     46º                  Theobroma                0.5405    Regular
# 49     47º         Machadinho d'Oeste                0.5322    Regular
# 50     48º     Campo Novo de Rondônia                0.5272    Regular
# 51     49º                Nova Mamoré                0.5084    Regular
# 52     50º                    Cujubim                0.5055    Regular
# 53     51º    Alto Alegre dos Parecis                0.5046    Regular
# 54     52º  Governador Jorge Teixeira                0.4562    Regular

# %% [markdown]
# ### 5.3 PIB
# C - https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_de_Rond%C3%B4nia_por_PIB

# %%
url = 'https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_de_Rond%C3%B4nia_por_PIB'

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; WIN64; x64)"
    "AppleWebKit/537.36 (KHTML, like Gecko)"
    "Chrome/124.0 Safari/537.36"
}

resp = requests.get(url, headers=headers)
resp.raise_for_status()

tables = pd.read_html(resp.text)
# Out:
# C:\Users\hfasa\AppData\Local\Temp\ipykernel_32692\2042433272.py:10: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text)

# %%
# Seleciona a primeira tabela da lista de tabelas lidas do site
tabela_de_referencia = tables[0]

# Tenta pegar o segundo nível das colunas (caso seja um MultiIndex)
# Isso só é necessário se a tabela tiver cabeçalho com múltiplas linhas
colunas_selecionadas = tables[0].columns.get_level_values(1)

# Substitui as colunas da tabela pelo segundo nível capturado
tabela_de_referencia.columns = colunas_selecionadas

# Seleciona apenas as colunas de interesse: Município, PIB e Variação
# tabela_de_referencia = tabela_de_referencia[['Município', 'PIB', 'Variação']]

# Exibe a tabela resultante
tabela_de_referencia
# Out:
#     Em 2021 Mudança (2020)                  Município         PIB  Variação
# 0         1            (0)                Porto Velho  20.059.522       NaN
# 1         2            (0)                  Ji-Paraná   4.231.113       NaN
# 2         3            (0)                    Vilhena   4.215.046       NaN
# 3         4            (0)                  Ariquemes   3.209.761       NaN
# 4         5            (0)                     Cacoal   2.792.383       NaN
# 5         6            (0)                       Jaru   1.765.089       NaN
# 6         7            (1)              Pimenta Bueno   1.642.516       NaN
# 7         8            (1)             Rolim de Moura   1.565.194       NaN
# 8         9            (0)              Guajará-Mirim   1.054.179       NaN
# 9        10            (0)        Ouro Preto do Oeste     985.868       NaN
# 10       11            (0)                    Buritis     966.552       NaN
# 11       12            (0)      São Miguel do Guaporé     905.335       NaN
# 12       13            (0)        Machadinho do Oeste     890.320       NaN
# 13       14            (0)            Espigão d'Oeste     773.381       NaN
# 14       15            (1)                 Cerejeiras     743.037       NaN
# 15       16            (1)                Nova Mamoré     742.687       NaN
# 16       17            (0)     Alta Floresta do Oeste     734.469       NaN
# 17       18            (0)         Candeias do Jamari     655.606       NaN
# 18       19            (0)          Presidente Médici     559.990       NaN
# 19       20            (1)  Nova Brasilândia do Oeste     548.734       NaN
# 20       21            (2)               Alto Paraíso     510.361       NaN
# 21       22            (0)   São Francisco do Guaporé     488.043       NaN
# 22       23            (3)                    Cujubim     487.480       NaN
# 23       24            (4)    Alto Alegre dos Parecis     483.672       NaN
# 24       25            (1)                Chupinguaia     468.793       NaN
# 25       26            (1)          Colorado do Oeste     424.807       NaN
# 26       27            (3)                 Corumbiara     396.728       NaN
# 27       28            (2)                Monte Negro     389.891       NaN
# 28       29            (2)     Campo Novo de Rondônia     369.377       NaN
# 29       30            (1)          Alvorada do Oeste     352.628       NaN
# 30       31            (1)               Seringueiras     332.987       NaN
# 31       32            (1)              Costa Marques     316.671       NaN
# 32       33            (2)         Ministro Andreazza     297.878       NaN
# 33       34            (7)                Cacaulândia     275.338       NaN
# 34       35            (1)                      Urupá     273.501       NaN
# 35       36            (3)           Mirante da Serra     262.640       NaN
# 36       37            (1)                  Theobroma     257.426       NaN
# 37       38            (7)       Pimenteiras do Oeste     246.209       NaN
# 38       39            (2)  Governador Jorge Teixeira     239.330       NaN
# 39       40            (2)                     Cabixi     238.412       NaN
# 40       41            (2)    Novo Horizonte do Oeste     231.502       NaN
# 41       42            (2)              Vale do Anari     220.588       NaN
# 42       43            (1)       Santa Luzia do Oeste     213.556       NaN
# 43       44            (6)            Itapuã do Oeste     210.031       NaN
# 44       45            (2)            Vale do Paraíso     185.648       NaN
# 45       46            (0)                 Rio Crespo     184.430       NaN
# 46       47            (0)                 Nova União     157.321       NaN
# 47       48            (0)                    Parecis     155.434       NaN
# 48       49            (0)        São Felipe do Oeste     130.676       NaN
# 49       50            (0)              Teixeirópolis     121.301       NaN
# 50       51            (1)      Primavera de Rondônia     107.030       NaN
# 51       52            (1)               Castanheiras      99.627       NaN

# %%
tabela_de_referencia['PIB'] = tabela_de_referencia['PIB'].str.replace(".","", regex=False).astype(float)

# %%
acima_de_1_bilhao = tabela_de_referencia.loc[tabela_de_referencia['PIB'] >= 1000000]
acima_de_500_milhoes = tabela_de_referencia.loc[tabela_de_referencia['PIB'] > 500000]
acima_de_300_milhoes = tabela_de_referencia.loc[tabela_de_referencia['PIB'] > 300000]
acima_de_200_milhoes = tabela_de_referencia.loc[tabela_de_referencia['PIB'] >= 200000]
acima_de_100_milhoes = tabela_de_referencia.loc[tabela_de_referencia['PIB'] >= 100000]
ate_100_milhoes = tabela_de_referencia.loc[tabela_de_referencia['PIB'] < 100000]

# %%
pib_tables = pd.concat([acima_de_1_bilhao, acima_de_500_milhoes, acima_de_300_milhoes, acima_de_200_milhoes, acima_de_100_milhoes, ate_100_milhoes], axis=0)

# %%
pib_tables
# Out:
#     Em 2021 Mudança (2020)              Município         PIB  Variação
# 0         1            (0)            Porto Velho  20059522.0       NaN
# 1         2            (0)              Ji-Paraná   4231113.0       NaN
# 2         3            (0)                Vilhena   4215046.0       NaN
# 3         4            (0)              Ariquemes   3209761.0       NaN
# 4         5            (0)                 Cacoal   2792383.0       NaN
# ..      ...            ...                    ...         ...       ...
# 47       48            (0)                Parecis    155434.0       NaN
# 48       49            (0)    São Felipe do Oeste    130676.0       NaN
# 49       50            (0)          Teixeirópolis    121301.0       NaN
# 50       51            (1)  Primavera de Rondônia    107030.0       NaN
# 51       52            (1)           Castanheiras     99627.0       NaN
#
# [158 rows x 5 columns]

# %%
pib_tables = pib_tables[['Município', 'PIB']]
pib_tables.reset_index(inplace=True, drop=True)
pib_tables.head(n=5)
# Out:
#      Município         PIB
# 0  Porto Velho  20059522.0
# 1    Ji-Paraná   4231113.0
# 2      Vilhena   4215046.0
# 3    Ariquemes   3209761.0
# 4       Cacoal   2792383.0

# %%
def categorize_pib(pib):
    if pib > 1000000:
        return 'Acima de 1 bilhão'
    elif pib > 500000:
        return 'Acima de 500 milhões'
    elif pib > 300000:
        return 'Acima de 300 milhões'
    elif pib > 200000:
        return 'Acima de 200 milhões'
    elif pib > 100000:
        return 'Acima de 100 milhões'
    else:
        return 'Até 100 milhões'

# %%
pib_tables['PIB'] = pd.to_numeric(pib_tables['PIB'], errors='coerce') # Remove tudo que não for número
# Out:
# C:\Users\hfasa\AppData\Local\Temp\ipykernel_32692\2465188408.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pib_tables['PIB'] = pd.to_numeric(pib_tables['PIB'], errors='coerce') # Remove tudo que não for número

# %%
pib_tables.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Município  158 non-null    object
#  1   PIB        158 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.6+ KB

# %%
pib_tables['faixa_pib'] = pib_tables.loc[:,'PIB'].apply(categorize_pib)
pib_tables.head(n=5)
# Out:
# C:\Users\hfasa\AppData\Local\Temp\ipykernel_32692\1484425671.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pib_tables['faixa_pib'] = pib_tables.loc[:,'PIB'].apply(categorize_pib)
#      Município         PIB          faixa_pib
# 0  Porto Velho  20059522.0  Acima de 1 bilhão
# 1    Ji-Paraná   4231113.0  Acima de 1 bilhão
# 2      Vilhena   4215046.0  Acima de 1 bilhão
# 3    Ariquemes   3209761.0  Acima de 1 bilhão
# 4       Cacoal   2792383.0  Acima de 1 bilhão

# %%
pib_tables.loc[pib_tables['faixa_pib'] == 'Acima de 500 milhões']
# Out:
#                      Município       PIB             faixa_pib
# 18         Ouro Preto do Oeste  985868.0  Acima de 500 milhões
# 19                     Buritis  966552.0  Acima de 500 milhões
# 20       São Miguel do Guaporé  905335.0  Acima de 500 milhões
# 21         Machadinho do Oeste  890320.0  Acima de 500 milhões
# 22             Espigão d'Oeste  773381.0  Acima de 500 milhões
# 23                  Cerejeiras  743037.0  Acima de 500 milhões
# 24                 Nova Mamoré  742687.0  Acima de 500 milhões
# 25      Alta Floresta do Oeste  734469.0  Acima de 500 milhões
# 26          Candeias do Jamari  655606.0  Acima de 500 milhões
# 27           Presidente Médici  559990.0  Acima de 500 milhões
# 28   Nova Brasilândia do Oeste  548734.0  Acima de 500 milhões
# 29                Alto Paraíso  510361.0  Acima de 500 milhões
# 39         Ouro Preto do Oeste  985868.0  Acima de 500 milhões
# 40                     Buritis  966552.0  Acima de 500 milhões
# 41       São Miguel do Guaporé  905335.0  Acima de 500 milhões
# 42         Machadinho do Oeste  890320.0  Acima de 500 milhões
# 43             Espigão d'Oeste  773381.0  Acima de 500 milhões
# 44                  Cerejeiras  743037.0  Acima de 500 milhões
# 45                 Nova Mamoré  742687.0  Acima de 500 milhões
# 46      Alta Floresta do Oeste  734469.0  Acima de 500 milhões
# 47          Candeias do Jamari  655606.0  Acima de 500 milhões
# 48           Presidente Médici  559990.0  Acima de 500 milhões
# 49   Nova Brasilândia do Oeste  548734.0  Acima de 500 milhões
# 50                Alto Paraíso  510361.0  Acima de 500 milhões
# 71         Ouro Preto do Oeste  985868.0  Acima de 500 milhões
# 72                     Buritis  966552.0  Acima de 500 milhões
# 73       São Miguel do Guaporé  905335.0  Acima de 500 milhões
# 74         Machadinho do Oeste  890320.0  Acima de 500 milhões
# 75             Espigão d'Oeste  773381.0  Acima de 500 milhões
# 76                  Cerejeiras  743037.0  Acima de 500 milhões
# 77                 Nova Mamoré  742687.0  Acima de 500 milhões
# 78      Alta Floresta do Oeste  734469.0  Acima de 500 milhões
# 79          Candeias do Jamari  655606.0  Acima de 500 milhões
# 80           Presidente Médici  559990.0  Acima de 500 milhões
# 81   Nova Brasilândia do Oeste  548734.0  Acima de 500 milhões
# 82                Alto Paraíso  510361.0  Acima de 500 milhões
# 115        Ouro Preto do Oeste  985868.0  Acima de 500 milhões
# 116                    Buritis  966552.0  Acima de 500 milhões
# 117      São Miguel do Guaporé  905335.0  Acima de 500 milhões
# 118        Machadinho do Oeste  890320.0  Acima de 500 milhões
# 119            Espigão d'Oeste  773381.0  Acima de 500 milhões
# 120                 Cerejeiras  743037.0  Acima de 500 milhões
# 121                Nova Mamoré  742687.0  Acima de 500 milhões
# 122     Alta Floresta do Oeste  734469.0  Acima de 500 milhões
# 123         Candeias do Jamari  655606.0  Acima de 500 milhões
# 124          Presidente Médici  559990.0  Acima de 500 milhões
# 125  Nova Brasilândia do Oeste  548734.0  Acima de 500 milhões
# 126               Alto Paraíso  510361.0  Acima de 500 milhões

# %% [markdown]
# ### Analise as respostas encontradas, tire algum insight delas, conte pra gente algo encontrado nos dados.

# %% [markdown]
# ### INSIGHTS
#
# - **Concentração de nascimentos:** A maioria dos nascimentos acontece em municípios com PIB acima de 1 bilhão. Isso pode refletir uma concentração maior de pessoas ou melhores condições de saúde nessas regiões.
#
# - **Escolaridade e IDH:** A escolaridade faz toda a diferença para o IDH de um município. Mulheres com níveis mais altos de estudo geralmente vivem em locais com índices de desenvolvimento humano melhores.
#
# - **Peso ao nascer e PIB:** O peso dos bebês só parece estar relacionado ao PIB nos municípios com PIB abaixo de 100 milhões. Nesses casos, os gráficos mostram uma queda significativa. Embora a diferença média de 50g pareça pequena, a curva deixa claro que existe uma redução mais acentuada nesses lugares e demonstra uma tendência de queda.
#
# - **Locais de nascimento:** Independente do IDH, os nascimentos praticamente só acontecem em hospitais. Em municípios menos desenvolvidos, como no estado de Roraima, os dados de 2019 mostram que não há partos em casa ou em outros tipos de estabelecimentos de saúde.
#
# - **Registro de pais:** O registro de pais no nascimento dos filhos é bem parecido em todas as categorias de IDH. Não importa se o município tem IDH alto, médio ou baixo, o comportamento é praticamente o mesmo.

# %%
sinasc_raw.head(n=5)
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  CODMUNRES  \
# 0      8 a 11 anos         NaN         0.0         0.0     110001
# 1      8 a 11 anos    999992.0         1.0         0.0     110001
# 2      8 a 11 anos    513205.0         2.0         0.0     110001
# 3  12 anos ou mais    231205.0         0.0         0.0     110037
# 4      8 a 11 anos    999992.0         1.0         0.0     110001
#
#           GESTACAO GRAVIDEZ    PARTO  CONSULTAS     DTNASC  HORANASC  \
# 0  37 a 41 semanas    Única  Cesáreo          4 2019-02-19    1620.0
# 1  37 a 41 semanas    Única  Cesáreo          4 2019-02-21    1830.0
# 2  37 a 41 semanas    Única  Cesáreo          4 2019-02-25     915.0
# 3  37 a 41 semanas    Única  Cesáreo          3 2019-03-20     835.0
# 4  37 a 41 semanas    Única  Cesáreo          4 2019-03-23     750.0
#
#         SEXO  APGAR1  APGAR5 RACACOR  PESO  IDANOMAL  DTCADASTRO CODANOMAL  \
# 0  Masculino     9.0    10.0  Branca  3685       2.0  2019-03-08       NaN
# 1   Feminino     8.0     9.0  Branca  3055       2.0  2019-03-08       NaN
# 2   Feminino     8.0    10.0  Branca  3460       2.0  2019-03-08       NaN
# 3   Feminino     9.0    10.0   Parda  2982       2.0  2019-04-03       NaN
# 4   Feminino     8.0    10.0   Parda  3310       2.0  2019-04-03       NaN
#
#    NUMEROLOTE VERSAOSIST   DTRECEBIM  DIFDATA  DTRECORIGA  NATURALMAE  \
# 0    20190004     3.2.01  2019-03-08       17         NaN       811.0
# 1    20190004     3.2.01  2019-03-08       15         NaN       811.0
# 2    20190004     3.2.01  2019-03-08       11         NaN       841.0
# 3    20190005     3.2.01  2019-04-09       20         NaN       841.0
# 4    20190005     3.2.01  2019-04-09       17         NaN       811.0
#
#    CODMUNNATU  CODUFNATU  ESCMAE2010  SERIESCMAE   DTNASCMAE  RACACORMAE  \
# 0    110001.0       11.0         3.0         NaN  20121999.0         1.0
# 1    110015.0       11.0         3.0         NaN  27041989.0         1.0
# 2    410045.0       41.0         3.0         NaN   6031981.0         1.0
# 3    410480.0       41.0         5.0         NaN  15071988.0         4.0
# 4    110001.0       11.0         3.0         NaN  12111988.0         4.0
#
#    QTDGESTANT  QTDPARTNOR  QTDPARTCES  IDADEPAI  DTULTMENST  SEMAGESTAC  \
# 0         0.0         0.0         0.0      26.0  15052018.0        39.0
# 1         1.0         0.0         1.0      24.0  27052018.0        38.0
# 2         2.0         1.0         1.0      32.0  18052018.0        40.0
# 3         0.0         0.0         0.0      24.0  25062018.0        38.0
# 4         1.0         0.0         1.0      27.0  27062018.0        38.0
#
#    TPMETESTIM  CONSPRENAT  MESPRENAT  TPAPRESENT  STTRABPART  STCESPARTO  \
# 0         8.0         8.0        1.0         1.0         2.0         2.0
# 1         8.0        10.0        2.0         1.0         2.0         2.0
# 2         8.0         8.0        1.0         2.0         2.0         2.0
# 3         8.0         6.0        2.0         1.0         2.0         1.0
# 4         8.0         8.0        2.0         1.0         2.0         1.0
#
#    TPNASCASSI  TPFUNCRESP  TPDOCRESP  DTDECLARAC  ESCMAEAGR1  STDNEPIDEM  \
# 0         1.0         2.0        3.0  19022019.0        12.0           0
# 1         1.0         5.0        4.0  21022019.0        12.0           0
# 2         1.0         2.0        4.0  25022019.0        12.0           0
# 3         1.0         2.0        3.0  20032019.0         8.0           0
# 4         1.0         2.0        3.0  23032019.0        12.0           0
#
#    STDNNOVA  CODPAISRES  TPROBSON  PARIDADE  KOTELCHUCK  CONTADOR  \
# 0         1           1         1         0           5         1
# 1         1           1         5         1           5         2
# 2         1           1         7         1           5         3
# 3         1           1         2         0           4         4
# 4         1           1         5         1           5         5
#
#   munResStatus munResTipo               munResNome  munResUf  munResLat  \
# 0        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia  -11.93554
# 1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia  -11.93554
# 2        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia  -11.93554
# 3        ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia  -12.13178
# 4        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia  -11.93554
#
#    munResLon  munResAlt  munResArea   faixa_latitude     faixa_area  \
# 0  -61.99982      338.0    7067.025  Abaixo de -10.5  Acima de 3000
# 1  -61.99982      338.0    7067.025  Abaixo de -10.5  Acima de 3000
# 2  -61.99982      338.0    7067.025  Abaixo de -10.5  Acima de 3000
# 3  -61.85308      397.0    3958.273  Abaixo de -10.5  Acima de 3000
# 4  -61.99982      338.0    7067.025  Abaixo de -10.5  Acima de 3000
#
#   faixa_de_altitude regiao_imediata  ano_mes
# 0   Entre 300 e 500          Cacoal  2019-02
# 1   Entre 300 e 500          Cacoal  2019-02
# 2   Entre 300 e 500          Cacoal  2019-02
# 3   Entre 300 e 500          Cacoal  2019-03
# 4   Entre 300 e 500          Cacoal  2019-03

# %%
sinasc_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27028 entries, 0 to 27027
# Data columns (total 74 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ORIGEM             27028 non-null  int64
#  1   CODESTAB           26913 non-null  float64
#  2   CODMUNNASC         27028 non-null  int64
#  3   LOCNASC            27028 non-null  int64
#  4   IDADEMAE           27028 non-null  int64
#  5   ESTCIVMAE          26711 non-null  float64
#  6   ESCMAE             26716 non-null  object
#  7   CODOCUPMAE         24121 non-null  float64
#  8   QTDFILVIVO         25455 non-null  float64
#  9   QTDFILMORT         24930 non-null  float64
#  10  CODMUNRES          27028 non-null  int64
#  11  GESTACAO           25796 non-null  object
#  12  GRAVIDEZ           26949 non-null  object
#  13  PARTO              26979 non-null  object
#  14  CONSULTAS          27028 non-null  int64
#  15  DTNASC             27028 non-null  datetime64[ns]
#  16  HORANASC           27007 non-null  float64
#  17  SEXO               27024 non-null  object
#  18  APGAR1             26932 non-null  float64
#  19  APGAR5             26925 non-null  float64
#  20  RACACOR            26381 non-null  object
#  21  PESO               27028 non-null  int64
#  22  IDANOMAL           26437 non-null  float64
#  23  DTCADASTRO         27028 non-null  object
#  24  CODANOMAL          214 non-null    object
#  25  NUMEROLOTE         27028 non-null  int64
#  26  VERSAOSIST         27028 non-null  object
#  27  DTRECEBIM          27028 non-null  object
#  28  DIFDATA            27028 non-null  int64
#  29  DTRECORIGA         0 non-null      float64
#  30  NATURALMAE         26730 non-null  float64
#  31  CODMUNNATU         26730 non-null  float64
#  32  CODUFNATU          26730 non-null  float64
#  33  ESCMAE2010         26779 non-null  float64
#  34  SERIESCMAE         14318 non-null  float64
#  35  DTNASCMAE          26988 non-null  float64
#  36  RACACORMAE         26367 non-null  float64
#  37  QTDGESTANT         25816 non-null  float64
#  38  QTDPARTNOR         25149 non-null  float64
#  39  QTDPARTCES         25237 non-null  float64
#  40  IDADEPAI           7607 non-null   float64
#  41  DTULTMENST         16956 non-null  float64
#  42  SEMAGESTAC         25790 non-null  float64
#  43  TPMETESTIM         25790 non-null  float64
#  44  CONSPRENAT         26098 non-null  float64
#  45  MESPRENAT          24161 non-null  float64
#  46  TPAPRESENT         26763 non-null  float64
#  47  STTRABPART         26081 non-null  float64
#  48  STCESPARTO         26281 non-null  float64
#  49  TPNASCASSI         26967 non-null  float64
#  50  TPFUNCRESP         26961 non-null  float64
#  51  TPDOCRESP          27014 non-null  float64
#  52  DTDECLARAC         26976 non-null  float64
#  53  ESCMAEAGR1         26779 non-null  float64
#  54  STDNEPIDEM         27028 non-null  int64
#  55  STDNNOVA           27028 non-null  int64
#  56  CODPAISRES         27028 non-null  int64
#  57  TPROBSON           27028 non-null  int64
#  58  PARIDADE           27028 non-null  int64
#  59  KOTELCHUCK         27028 non-null  int64
#  60  CONTADOR           27028 non-null  int64
#  61  munResStatus       27028 non-null  object
#  62  munResTipo         27028 non-null  object
#  63  munResNome         27028 non-null  object
#  64  munResUf           27028 non-null  object
#  65  munResLat          27027 non-null  float64
#  66  munResLon          27027 non-null  float64
#  67  munResAlt          27027 non-null  float64
#  68  munResArea         27027 non-null  float64
#  69  faixa_latitude     27027 non-null  category
#  70  faixa_area         27027 non-null  category
#  71  faixa_de_altitude  27027 non-null  category
#  72  regiao_imediata    27027 non-null  object
#  73  ano_mes            27028 non-null  period[M]
# dtypes: category(3), datetime64[ns](1), float64(38), int64(16), object(15), period[M](1)
# memory usage: 14.7+ MB

# %%
sinasc_1 = pd.merge(sinasc_raw, idh_table, left_on='munResNome', right_on='Município')
sinasc_1 = pd.merge(sinasc_1, ifdm_table, left_on='munResNome', right_on='Município')
sinasc_1 = pd.merge(sinasc_1, pib_tables, left_on='munResNome', right_on='Município')

sinasc_1
# Out:
#         ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0            1  2516500.0      110001        1        30        5.0
# 1            1  2516500.0      110001        1        30        5.0
# 2            1  2516500.0      110001        1        30        5.0
# 3            1  2516500.0      110001        1        26        2.0
# 4            1  2516500.0      110001        1        26        2.0
# ...        ...        ...         ...      ...       ...        ...
# 113447       1  2798484.0      110030        1        22        1.0
# 113448       1  2798484.0      110030        1        32        4.0
# 113449       1  2798484.0      110030        1        32        4.0
# 113450       1  2798484.0      110030        1        30        2.0
# 113451       1  2798484.0      110030        1        30        2.0
#
#                  ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  CODMUNRES  \
# 0       12 anos ou mais    231205.0         0.0         0.0     110037
# 1       12 anos ou mais    231205.0         0.0         0.0     110037
# 2       12 anos ou mais    231205.0         0.0         0.0     110037
# 3           8 a 11 anos    999992.0         2.0         0.0     110037
# 4           8 a 11 anos    999992.0         2.0         0.0     110037
# ...                 ...         ...         ...         ...        ...
# 113447      8 a 11 anos    999992.0         0.0         0.0     110003
# 113448      8 a 11 anos    999992.0         1.0         2.0     110003
# 113449      8 a 11 anos    999992.0         1.0         2.0     110003
# 113450      8 a 11 anos    763010.0         1.0         0.0     110003
# 113451      8 a 11 anos    763010.0         1.0         0.0     110003
#
#                GESTACAO GRAVIDEZ    PARTO  CONSULTAS     DTNASC  HORANASC  \
# 0       37 a 41 semanas    Única  Cesáreo          3 2019-03-20     835.0
# 1       37 a 41 semanas    Única  Cesáreo          3 2019-03-20     835.0
# 2       37 a 41 semanas    Única  Cesáreo          3 2019-03-20     835.0
# 3       37 a 41 semanas    Dupla  Cesáreo          4 2019-04-08    1050.0
# 4       37 a 41 semanas    Dupla  Cesáreo          4 2019-04-08    1050.0
# ...                 ...      ...      ...        ...        ...       ...
# 113447  37 a 41 semanas    Única  Vaginal          4 2019-12-18    1840.0
# 113448  37 a 41 semanas    Única  Cesáreo          4 2019-12-19    1208.0
# 113449  37 a 41 semanas    Única  Cesáreo          4 2019-12-19    1208.0
# 113450  37 a 41 semanas    Única  Cesáreo          4 2019-12-22    1506.0
# 113451  37 a 41 semanas    Única  Cesáreo          4 2019-12-22    1506.0
#
#              SEXO  APGAR1  APGAR5 RACACOR  PESO  IDANOMAL  DTCADASTRO  \
# 0        Feminino     9.0    10.0   Parda  2982       2.0  2019-04-03
# 1        Feminino     9.0    10.0   Parda  2982       2.0  2019-04-03
# 2        Feminino     9.0    10.0   Parda  2982       2.0  2019-04-03
# 3       Masculino     9.0    10.0   Parda  2480       2.0  2019-05-08
# 4       Masculino     9.0    10.0   Parda  2480       2.0  2019-05-08
# ...           ...     ...     ...     ...   ...       ...         ...
# 113447   Feminino     8.0     9.0   Parda  2660       2.0  2019-12-30
# 113448   Feminino     9.0     9.0   Parda  2235       1.0  2020-01-02
# 113449   Feminino     9.0     9.0   Parda  2235       1.0  2020-01-02
# 113450  Masculino     7.0     8.0   Parda  3280       2.0  2020-01-02
# 113451  Masculino     7.0     8.0   Parda  3280       2.0  2020-01-02
#
#                CODANOMAL  NUMEROLOTE VERSAOSIST   DTRECEBIM  DIFDATA  \
# 0                    NaN    20190005     3.2.01  2019-04-09       20
# 1                    NaN    20190005     3.2.01  2019-04-09       20
# 2                    NaN    20190005     3.2.01  2019-04-09       20
# 3                    NaN    20190006     3.2.01  2019-05-09       31
# 4                    NaN    20190006     3.2.01  2019-05-09       31
# ...                  ...         ...        ...         ...      ...
# 113447               NaN    20200001     3.2.01  2020-01-09       22
# 113448  Q175Q178Q385Q909    20200001     3.2.01  2020-01-09       21
# 113449  Q175Q178Q385Q909    20200001     3.2.01  2020-01-09       21
# 113450               NaN    20200001     3.2.01  2020-01-09       18
# 113451               NaN    20200001     3.2.01  2020-01-09       18
#
#         DTRECORIGA  NATURALMAE  CODMUNNATU  CODUFNATU  ESCMAE2010  SERIESCMAE  \
# 0              NaN       841.0    410480.0       41.0         5.0         NaN
# 1              NaN       841.0    410480.0       41.0         5.0         NaN
# 2              NaN       841.0    410480.0       41.0         5.0         NaN
# 3              NaN       811.0    110004.0       11.0         3.0         NaN
# 4              NaN       811.0    110004.0       11.0         3.0         NaN
# ...            ...         ...         ...        ...         ...         ...
# 113447         NaN       831.0    313960.0       31.0         3.0         3.0
# 113448         NaN       811.0    110020.0       11.0         3.0         3.0
# 113449         NaN       811.0    110020.0       11.0         3.0         3.0
# 113450         NaN       811.0    110003.0       11.0         3.0         3.0
# 113451         NaN       811.0    110003.0       11.0         3.0         3.0
#
#          DTNASCMAE  RACACORMAE  QTDGESTANT  QTDPARTNOR  QTDPARTCES  IDADEPAI  \
# 0       15071988.0         4.0         0.0         0.0         0.0      24.0
# 1       15071988.0         4.0         0.0         0.0         0.0      24.0
# 2       15071988.0         4.0         0.0         0.0         0.0      24.0
# 3       28071992.0         4.0         2.0         0.0         2.0      43.0
# 4       28071992.0         4.0         2.0         0.0         2.0      43.0
# ...            ...         ...         ...         ...         ...       ...
# 113447  18101997.0         4.0         0.0         0.0         0.0       NaN
# 113448  30111987.0         4.0         3.0         1.0         0.0       NaN
# 113449  30111987.0         4.0         3.0         1.0         0.0       NaN
# 113450   6071989.0         4.0         1.0         0.0         1.0       NaN
# 113451   6071989.0         4.0         1.0         0.0         1.0       NaN
#
#         DTULTMENST  SEMAGESTAC  TPMETESTIM  CONSPRENAT  MESPRENAT  TPAPRESENT  \
# 0       25062018.0        38.0         8.0         6.0        2.0         1.0
# 1       25062018.0        38.0         8.0         6.0        2.0         1.0
# 2       25062018.0        38.0         8.0         6.0        2.0         1.0
# 3       14072018.0        38.0         8.0        11.0        2.0         1.0
# 4       14072018.0        38.0         8.0        11.0        2.0         1.0
# ...            ...         ...         ...         ...        ...         ...
# 113447  27032019.0        38.0         8.0        10.0        3.0         1.0
# 113448  27032019.0        38.0         8.0        19.0        3.0         3.0
# 113449  27032019.0        38.0         8.0        19.0        3.0         3.0
# 113450   6042019.0        37.0         8.0        13.0        2.0         1.0
# 113451   6042019.0        37.0         8.0        13.0        2.0         1.0
#
#         STTRABPART  STCESPARTO  TPNASCASSI  TPFUNCRESP  TPDOCRESP  DTDECLARAC  \
# 0              2.0         1.0         1.0         2.0        3.0  20032019.0
# 1              2.0         1.0         1.0         2.0        3.0  20032019.0
# 2              2.0         1.0         1.0         2.0        3.0  20032019.0
# 3              2.0         1.0         1.0         2.0        5.0   8042019.0
# 4              2.0         1.0         1.0         2.0        5.0   8042019.0
# ...            ...         ...         ...         ...        ...         ...
# 113447         2.0         3.0         2.0         5.0        0.0  19122019.0
# 113448         2.0         1.0         1.0         5.0        0.0  19122019.0
# 113449         2.0         1.0         1.0         5.0        0.0  19122019.0
# 113450         2.0         2.0         1.0         5.0        0.0  23122019.0
# 113451         2.0         2.0         1.0         5.0        0.0  23122019.0
#
#         ESCMAEAGR1  STDNEPIDEM  STDNNOVA  CODPAISRES  TPROBSON  PARIDADE  \
# 0              8.0           0         1           1         2         0
# 1              8.0           0         1           1         2         0
# 2              8.0           0         1           1         2         0
# 3             12.0           0         1           1         8         1
# 4             12.0           0         1           1         8         1
# ...            ...         ...       ...         ...       ...       ...
# 113447         6.0           0         1           1         1         0
# 113448         6.0           0         1           1         9         1
# 113449         6.0           0         1           1         9         1
# 113450         6.0           0         1           1         5         1
# 113451         6.0           0         1           1         5         1
#
#         KOTELCHUCK  CONTADOR munResStatus munResTipo               munResNome  \
# 0                4         4        ATIVO      MUNIC  Alto Alegre dos Parecis
# 1                4         4        ATIVO      MUNIC  Alto Alegre dos Parecis
# 2                4         4        ATIVO      MUNIC  Alto Alegre dos Parecis
# 3                5        24        ATIVO      MUNIC  Alto Alegre dos Parecis
# 4                5        24        ATIVO      MUNIC  Alto Alegre dos Parecis
# ...            ...       ...          ...        ...                      ...
# 113447           5   1492602        ATIVO      MUNIC                   Cabixi
# 113448           5   1492603        ATIVO      MUNIC                   Cabixi
# 113449           5   1492603        ATIVO      MUNIC                   Cabixi
# 113450           5   1492618        ATIVO      MUNIC                   Cabixi
# 113451           5   1492618        ATIVO      MUNIC                   Cabixi
#
#         munResUf  munResLat  munResLon  munResAlt  munResArea  \
# 0       Rondônia  -12.13178  -61.85308      397.0    3958.273
# 1       Rondônia  -12.13178  -61.85308      397.0    3958.273
# 2       Rondônia  -12.13178  -61.85308      397.0    3958.273
# 3       Rondônia  -12.13178  -61.85308      397.0    3958.273
# 4       Rondônia  -12.13178  -61.85308      397.0    3958.273
# ...          ...        ...        ...        ...         ...
# 113447  Rondônia  -13.49976  -60.54431      236.0    1314.352
# 113448  Rondônia  -13.49976  -60.54431      236.0    1314.352
# 113449  Rondônia  -13.49976  -60.54431      236.0    1314.352
# 113450  Rondônia  -13.49976  -60.54431      236.0    1314.352
# 113451  Rondônia  -13.49976  -60.54431      236.0    1314.352
#
#          faixa_latitude      faixa_area faixa_de_altitude regiao_imediata  \
# 0       Abaixo de -10.5   Acima de 3000   Entre 300 e 500          Cacoal
# 1       Abaixo de -10.5   Acima de 3000   Entre 300 e 500          Cacoal
# 2       Abaixo de -10.5   Acima de 3000   Entre 300 e 500          Cacoal
# 3       Abaixo de -10.5   Acima de 3000   Entre 300 e 500          Cacoal
# 4       Abaixo de -10.5   Acima de 3000   Entre 300 e 500          Cacoal
# ...                 ...             ...               ...             ...
# 113447  Abaixo de -10.5  Abaixo de 3000   Entre 100 e 300         Vilhena
# 113448  Abaixo de -10.5  Abaixo de 3000   Entre 100 e 300         Vilhena
# 113449  Abaixo de -10.5  Abaixo de 3000   Entre 100 e 300         Vilhena
# 113450  Abaixo de -10.5  Abaixo de 3000   Entre 100 e 300         Vilhena
# 113451  Abaixo de -10.5  Abaixo de 3000   Entre 100 e 300         Vilhena
#
#         ano_mes Posição_x              Município_x    IDH faixa_idh Posição_y  \
# 0       2019-03        48  Alto Alegre dos Parecis  0.592     Baixo       51º
# 1       2019-03        48  Alto Alegre dos Parecis  0.592     Baixo       51º
# 2       2019-03        48  Alto Alegre dos Parecis  0.592     Baixo       51º
# 3       2019-04        48  Alto Alegre dos Parecis  0.592     Baixo       51º
# 4       2019-04        48  Alto Alegre dos Parecis  0.592     Baixo       51º
# ...         ...       ...                      ...    ...       ...       ...
# 113447  2019-12        19                   Cabixi   0.65     Médio       31º
# 113448  2019-12        19                   Cabixi   0.65     Médio       31º
# 113449  2019-12        19                   Cabixi   0.65     Médio       31º
# 113450  2019-12        19                   Cabixi   0.65     Médio       31º
# 113451  2019-12        19                   Cabixi   0.65     Médio       31º
#
#                     Município_y IFDM_Consolidado_2013 faixa_ifdm  \
# 0       Alto Alegre dos Parecis                0.5046    Regular
# 1       Alto Alegre dos Parecis                0.5046    Regular
# 2       Alto Alegre dos Parecis                0.5046    Regular
# 3       Alto Alegre dos Parecis                0.5046    Regular
# 4       Alto Alegre dos Parecis                0.5046    Regular
# ...                         ...                   ...        ...
# 113447                   Cabixi                0.5887    Regular
# 113448                   Cabixi                0.5887    Regular
# 113449                   Cabixi                0.5887    Regular
# 113450                   Cabixi                0.5887    Regular
# 113451                   Cabixi                0.5887    Regular
#
#                       Município       PIB             faixa_pib
# 0       Alto Alegre dos Parecis  483672.0  Acima de 300 milhões
# 1       Alto Alegre dos Parecis  483672.0  Acima de 300 milhões
# 2       Alto Alegre dos Parecis  483672.0  Acima de 300 milhões
# 3       Alto Alegre dos Parecis  483672.0  Acima de 300 milhões
# 4       Alto Alegre dos Parecis  483672.0  Acima de 300 milhões
# ...                         ...       ...                   ...
# 113447                   Cabixi  238412.0  Acima de 200 milhões
# 113448                   Cabixi  238412.0  Acima de 200 milhões
# 113449                   Cabixi  238412.0  Acima de 200 milhões
# 113450                   Cabixi  238412.0  Acima de 200 milhões
# 113451                   Cabixi  238412.0  Acima de 200 milhões
#
# [113452 rows x 85 columns]

# %%
sinasc_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113452 entries, 0 to 113451
# Data columns (total 85 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ORIGEM                 113452 non-null  int64
#  1   CODESTAB               112957 non-null  float64
#  2   CODMUNNASC             113452 non-null  int64
#  3   LOCNASC                113452 non-null  int64
#  4   IDADEMAE               113452 non-null  int64
#  5   ESTCIVMAE              112142 non-null  float64
#  6   ESCMAE                 112100 non-null  object
#  7   CODOCUPMAE             101761 non-null  float64
#  8   QTDFILVIVO             106201 non-null  float64
#  9   QTDFILMORT             103934 non-null  float64
#  10  CODMUNRES              113452 non-null  int64
#  11  GESTACAO               107860 non-null  object
#  12  GRAVIDEZ               113114 non-null  object
#  13  PARTO                  113239 non-null  object
#  14  CONSULTAS              113452 non-null  int64
#  15  DTNASC                 113452 non-null  datetime64[ns]
#  16  HORANASC               113360 non-null  float64
#  17  SEXO                   113434 non-null  object
#  18  APGAR1                 113031 non-null  float64
#  19  APGAR5                 113007 non-null  float64
#  20  RACACOR                110892 non-null  object
#  21  PESO                   113452 non-null  int64
#  22  IDANOMAL               110579 non-null  float64
#  23  DTCADASTRO             113452 non-null  object
#  24  CODANOMAL              909 non-null     object
#  25  NUMEROLOTE             113452 non-null  int64
#  26  VERSAOSIST             113452 non-null  object
#  27  DTRECEBIM              113452 non-null  object
#  28  DIFDATA                113452 non-null  int64
#  29  DTRECORIGA             0 non-null       float64
#  30  NATURALMAE             112166 non-null  float64
#  31  CODMUNNATU             112166 non-null  float64
#  32  CODUFNATU              112166 non-null  float64
#  33  ESCMAE2010             112411 non-null  float64
#  34  SERIESCMAE             58621 non-null   float64
#  35  DTNASCMAE              113304 non-null  float64
#  36  RACACORMAE             110856 non-null  float64
#  37  QTDGESTANT             107696 non-null  float64
#  38  QTDPARTNOR             104879 non-null  float64
#  39  QTDPARTCES             105191 non-null  float64
#  40  IDADEPAI               29010 non-null   float64
#  41  DTULTMENST             67696 non-null   float64
#  42  SEMAGESTAC             107848 non-null  float64
#  43  TPMETESTIM             107848 non-null  float64
#  44  CONSPRENAT             109186 non-null  float64
#  45  MESPRENAT              99952 non-null   float64
#  46  TPAPRESENT             112277 non-null  float64
#  47  STTRABPART             109037 non-null  float64
#  48  STCESPARTO             109993 non-null  float64
#  49  TPNASCASSI             113233 non-null  float64
#  50  TPFUNCRESP             113239 non-null  float64
#  51  TPDOCRESP              113416 non-null  float64
#  52  DTDECLARAC             113308 non-null  float64
#  53  ESCMAEAGR1             112411 non-null  float64
#  54  STDNEPIDEM             113452 non-null  int64
#  55  STDNNOVA               113452 non-null  int64
#  56  CODPAISRES             113452 non-null  int64
#  57  TPROBSON               113452 non-null  int64
#  58  PARIDADE               113452 non-null  int64
#  59  KOTELCHUCK             113452 non-null  int64
#  60  CONTADOR               113452 non-null  int64
#  61  munResStatus           113452 non-null  object
#  62  munResTipo             113452 non-null  object
#  63  munResNome             113452 non-null  object
#  64  munResUf               113452 non-null  object
#  65  munResLat              113452 non-null  float64
#  66  munResLon              113452 non-null  float64
#  67  munResAlt              113452 non-null  float64
#  68  munResArea             113452 non-null  float64
#  69  faixa_latitude         113452 non-null  category
#  70  faixa_area             113452 non-null  category
#  71  faixa_de_altitude      113452 non-null  category
#  72  regiao_imediata        113452 non-null  object
#  73  ano_mes                113452 non-null  period[M]
#  74  Posição_x              113452 non-null  object
#  75  Município_x            113452 non-null  object
#  76  IDH                    113452 non-null  object
#  77  faixa_idh              113452 non-null  object
#  78  Posição_y              113452 non-null  object
#  79  Município_y            113452 non-null  object
#  80  IFDM_Consolidado_2013  113452 non-null  object
#  81  faixa_ifdm             113452 non-null  object
#  82  Município              113452 non-null  object
#  83  PIB                    113452 non-null  float64
#  84  faixa_pib              113452 non-null  object
# dtypes: category(3), datetime64[ns](1), float64(39), int64(16), object(25), period[M](1)
# memory usage: 71.3+ MB

# %%
sinasc_1 = sinasc_1[['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
       'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
       'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
       'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
       'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
       'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
       'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
       'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
       'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
       'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
       'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
       'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
       'munResUf', 'munResLat', 'munResLon', 'munResAlt', 'munResArea',
       'faixa_latitude', 'faixa_area', 'faixa_de_altitude', 'regiao_imediata',
       'ano_mes', 'IDH', 'faixa_idh',
       'IFDM_Consolidado_2013', 'faixa_ifdm',
       'PIB', 'faixa_pib']]
sinasc_1.head(n=5)
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2516500.0      110001        1        30        5.0
# 1       1  2516500.0      110001        1        30        5.0
# 2       1  2516500.0      110001        1        30        5.0
# 3       1  2516500.0      110001        1        26        2.0
# 4       1  2516500.0      110001        1        26        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  CODMUNRES  \
# 0  12 anos ou mais    231205.0         0.0         0.0     110037
# 1  12 anos ou mais    231205.0         0.0         0.0     110037
# 2  12 anos ou mais    231205.0         0.0         0.0     110037
# 3      8 a 11 anos    999992.0         2.0         0.0     110037
# 4      8 a 11 anos    999992.0         2.0         0.0     110037
#
#           GESTACAO GRAVIDEZ    PARTO  CONSULTAS     DTNASC  HORANASC  \
# 0  37 a 41 semanas    Única  Cesáreo          3 2019-03-20     835.0
# 1  37 a 41 semanas    Única  Cesáreo          3 2019-03-20     835.0
# 2  37 a 41 semanas    Única  Cesáreo          3 2019-03-20     835.0
# 3  37 a 41 semanas    Dupla  Cesáreo          4 2019-04-08    1050.0
# 4  37 a 41 semanas    Dupla  Cesáreo          4 2019-04-08    1050.0
#
#         SEXO  APGAR1  APGAR5 RACACOR  PESO  IDANOMAL  DTCADASTRO CODANOMAL  \
# 0   Feminino     9.0    10.0   Parda  2982       2.0  2019-04-03       NaN
# 1   Feminino     9.0    10.0   Parda  2982       2.0  2019-04-03       NaN
# 2   Feminino     9.0    10.0   Parda  2982       2.0  2019-04-03       NaN
# 3  Masculino     9.0    10.0   Parda  2480       2.0  2019-05-08       NaN
# 4  Masculino     9.0    10.0   Parda  2480       2.0  2019-05-08       NaN
#
#    NUMEROLOTE VERSAOSIST   DTRECEBIM  DIFDATA  DTRECORIGA  NATURALMAE  \
# 0    20190005     3.2.01  2019-04-09       20         NaN       841.0
# 1    20190005     3.2.01  2019-04-09       20         NaN       841.0
# 2    20190005     3.2.01  2019-04-09       20         NaN       841.0
# 3    20190006     3.2.01  2019-05-09       31         NaN       811.0
# 4    20190006     3.2.01  2019-05-09       31         NaN       811.0
#
#    CODMUNNATU  CODUFNATU  ESCMAE2010  SERIESCMAE   DTNASCMAE  RACACORMAE  \
# 0    410480.0       41.0         5.0         NaN  15071988.0         4.0
# 1    410480.0       41.0         5.0         NaN  15071988.0         4.0
# 2    410480.0       41.0         5.0         NaN  15071988.0         4.0
# 3    110004.0       11.0         3.0         NaN  28071992.0         4.0
# 4    110004.0       11.0         3.0         NaN  28071992.0         4.0
#
#    QTDGESTANT  QTDPARTNOR  QTDPARTCES  IDADEPAI  DTULTMENST  SEMAGESTAC  \
# 0         0.0         0.0         0.0      24.0  25062018.0        38.0
# 1         0.0         0.0         0.0      24.0  25062018.0        38.0
# 2         0.0         0.0         0.0      24.0  25062018.0        38.0
# 3         2.0         0.0         2.0      43.0  14072018.0        38.0
# 4         2.0         0.0         2.0      43.0  14072018.0        38.0
#
#    TPMETESTIM  CONSPRENAT  MESPRENAT  TPAPRESENT  STTRABPART  STCESPARTO  \
# 0         8.0         6.0        2.0         1.0         2.0         1.0
# 1         8.0         6.0        2.0         1.0         2.0         1.0
# 2         8.0         6.0        2.0         1.0         2.0         1.0
# 3         8.0        11.0        2.0         1.0         2.0         1.0
# 4         8.0        11.0        2.0         1.0         2.0         1.0
#
#    TPNASCASSI  TPFUNCRESP  TPDOCRESP  DTDECLARAC  ESCMAEAGR1  STDNEPIDEM  \
# 0         1.0         2.0        3.0  20032019.0         8.0           0
# 1         1.0         2.0        3.0  20032019.0         8.0           0
# 2         1.0         2.0        3.0  20032019.0         8.0           0
# 3         1.0         2.0        5.0   8042019.0        12.0           0
# 4         1.0         2.0        5.0   8042019.0        12.0           0
#
#    STDNNOVA  CODPAISRES  TPROBSON  PARIDADE  KOTELCHUCK  CONTADOR  \
# 0         1           1         2         0           4         4
# 1         1           1         2         0           4         4
# 2         1           1         2         0           4         4
# 3         1           1         8         1           5        24
# 4         1           1         8         1           5        24
#
#   munResStatus munResTipo               munResNome  munResUf  munResLat  \
# 0        ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia  -12.13178
# 1        ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia  -12.13178
# 2        ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia  -12.13178
# 3        ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia  -12.13178
# 4        ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia  -12.13178
#
#    munResLon  munResAlt  munResArea   faixa_latitude     faixa_area  \
# 0  -61.85308      397.0    3958.273  Abaixo de -10.5  Acima de 3000
# 1  -61.85308      397.0    3958.273  Abaixo de -10.5  Acima de 3000
# 2  -61.85308      397.0    3958.273  Abaixo de -10.5  Acima de 3000
# 3  -61.85308      397.0    3958.273  Abaixo de -10.5  Acima de 3000
# 4  -61.85308      397.0    3958.273  Abaixo de -10.5  Acima de 3000
#
#   faixa_de_altitude regiao_imediata  ano_mes    IDH faixa_idh  \
# 0   Entre 300 e 500          Cacoal  2019-03  0.592     Baixo
# 1   Entre 300 e 500          Cacoal  2019-03  0.592     Baixo
# 2   Entre 300 e 500          Cacoal  2019-03  0.592     Baixo
# 3   Entre 300 e 500          Cacoal  2019-04  0.592     Baixo
# 4   Entre 300 e 500          Cacoal  2019-04  0.592     Baixo
#
#   IFDM_Consolidado_2013 faixa_ifdm       PIB             faixa_pib
# 0                0.5046    Regular  483672.0  Acima de 300 milhões
# 1                0.5046    Regular  483672.0  Acima de 300 milhões
# 2                0.5046    Regular  483672.0  Acima de 300 milhões
# 3                0.5046    Regular  483672.0  Acima de 300 milhões
# 4                0.5046    Regular  483672.0  Acima de 300 milhões

# %%
sinasc_1.groupby('faixa_pib')['IDADEMAE'].count().plot(figsize=[18,6])
# Out:
# <Axes: xlabel='faixa_pib'>

# %%
results = sinasc_1.groupby('faixa_pib')['PESO'].mean()
results
# Out:
# faixa_pib
# Acima de 1 bilhão       3249.150780
# Acima de 100 milhões    3214.966321
# Acima de 200 milhões    3225.770945
# Acima de 300 milhões    3267.214397
# Acima de 500 milhões    3222.080567
# Até 100 milhões         3206.312500
# Name: PESO, dtype: float64

# %%
results.plot(figsize=[18,6])
# Out:
# <Axes: xlabel='faixa_pib'>

# %%
results = sinasc_1.groupby('faixa_idh')['PESO'].mean()
results.plot()
# Out:
# <Axes: xlabel='faixa_idh'>

# %%
results = sinasc_1.groupby('ESCMAE')['IDH'].mean()
results.plot(figsize=[15,3])
# Out:
# <Axes: xlabel='ESCMAE'>

# %%
results = sinasc_1.groupby(['ESCMAE', 'faixa_idh'])['IDADEMAE'].mean().unstack()

plt.figure(figsize=[12,6])
for idh in results.columns:
    plt.plot(results.index, results[idh], label=idh)
    plt.legend()

plt.show()

# %%
results = sinasc_1.groupby(['LOCNASC', 'faixa_idh'])['IDADEMAE'].count().unstack()
results
# Out:
# faixa_idh   Alto  Baixo  Médio
# LOCNASC
# 1          83930   3850  25040
# 2             65     12     60
# 3            185     17    133
# 4             95     21     44

# %%
sinasc_1['LOCNASC'].unique()
# Out:
# array([1, 3, 2, 4], dtype=int64)

# %%
fig, ax = plt.subplots()
for idh in results.columns:
    ax.plot(results.index, results[idh], label = idh)
    ax.legend()
    
ax.set_xticks(results.index)
ax.set_xticklabels(['Hospital',  'Outros Estabelecimentos de saúde',  'Domicilio',  'Outros'], rotation=30)

plt.show()

# %%
sinasc_1['NumRegIDADEPAI'] = ~sinasc_1['IDADEPAI'].isna() # Criação de uma coluna que contabilize a confirmação do registro de IDADEPAI
results = sinasc_1.groupby(['NumRegIDADEPAI', 'faixa_idh'])['IDADEMAE'].count().unstack()
results
# Out:
# C:\Users\hfasa\AppData\Local\Temp\ipykernel_32692\1532073262.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sinasc_1['NumRegIDADEPAI'] = ~sinasc_1['IDADEPAI'].isna() # Criação de uma coluna que contabilize a confirmação do registro de IDADEPAI
# faixa_idh        Alto  Baixo  Médio
# NumRegIDADEPAI
# False           61735   3008  19699
# True            22540    892   5578

# %%
results_percentual = round((results/results.sum())*100,2)
results_percentual
# Out:
# faixa_idh        Alto  Baixo  Médio
# NumRegIDADEPAI
# False           73.25  77.13  77.93
# True            26.75  22.87  22.07

# %%
fig, ax = plt.subplots()
for idh in results_percentual.columns:
    ax.plot(results_percentual.index, results_percentual[idh],label = idh)
    ax.legend()
    ax.grid(True)
    
ax.set_xticks(results_percentual.index)   
ax.set_xticklabels(['Número de registros ausentes', 'Registros confirmados'])

plt.show()
